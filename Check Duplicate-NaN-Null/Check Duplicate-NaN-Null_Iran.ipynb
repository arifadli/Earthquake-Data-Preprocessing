# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import numpy as np
import graphviz
import math
import seaborn as sns

from datetime import datetime
from matplotlib import pyplot as plt
from IPython.display import Image
from datetime import timedelta
from scipy import optimize
from scipy import stats
from mpl_toolkits.mplot3d import axes3d
from matplotlib import pyplot as plt
from datetime import timedelta, datetime

# %matplotlib inline

# %% [markdown]
# #**Read Earthquake Datasset**

# %%
dataset1 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1972-1987.csv"
dataset2 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1988-1998.csv"
dataset3 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1999-2019.csv"
dataset4 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran2020-2022.csv"
# Load each dataset
df1 = pd.read_csv("https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1972-1987.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1988-1998.csv")
df3 = pd.read_csv("https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran1999-2019.csv")
df4 = pd.read_csv("https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Iran/Iran2020-2022.csv")

# Concatenate the datasets
merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Display the merged DataFrame
merged_df.head()
# Out:
#                        time  latitude  longitude  depth  mag magType  nst  \
# 0  1987-12-18T20:54:33.750Z    28.239     56.683   33.0  4.6      mb  NaN
# 1  1987-12-18T16:24:03.050Z    28.191     56.677   19.8  5.9      mw  NaN
# 2  1987-11-30T03:12:37.000Z    30.990     51.170   37.7  4.8      mb  NaN
# 3  1987-11-27T08:26:43.780Z    32.691     59.100   33.0  4.7      mb  NaN
# 4  1987-11-25T22:53:29.970Z    28.231     56.753   33.0  4.5      mb  NaN
#
#    gap  dmin  rms  ...                   updated  \
# 0  NaN   NaN  0.9  ...  2014-11-07T00:41:24.357Z
# 1  NaN   NaN  1.0  ...  2022-04-27T21:27:51.633Z
# 2  NaN   NaN  1.1  ...  2014-11-07T00:41:16.294Z
# 3  NaN   NaN  0.7  ...  2020-08-28T21:42:24.936Z
# 4  NaN   NaN  1.0  ...  2014-11-07T00:41:15.759Z
#
#                               place        type horizontalError depthError  \
# 0       115 km S of K?h Sef?d, Iran  earthquake             NaN        NaN
# 1  117 km NNE of Bandar Abbas, Iran  earthquake             NaN        NaN
# 2           53 km NW of Yasuj, Iran  earthquake             NaN        8.0
# 3                      Eastern Iran  earthquake             NaN        NaN
# 4       115 km S of K?h Sef?d, Iran  earthquake             NaN        NaN
#
#    magError  magNst    status  locationSource magSource
# 0       NaN    24.0  reviewed              us        us
# 1       NaN     NaN  reviewed              us       hrv
# 2       NaN    32.0  reviewed              us        us
# 3       NaN    26.0  reviewed              us        us
# 4       NaN    11.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
df = merged_df

# %%
# Mengambil hanya kolom yang diinginkan
selected_columns = ['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'net', 'id', 'updated', 'type', 'status', 'locationSource', 'magSource']
df_selected_columns = df[selected_columns]

# Menampilkan DataFrame yang hanya berisi kolom yang dipilih
df_selected_columns.head(10)
# Out:
#                        time  latitude  longitude  depth  mag magType net  \
# 0  1987-12-18T20:54:33.750Z    28.239     56.683   33.0  4.6      mb  us
# 1  1987-12-18T16:24:03.050Z    28.191     56.677   19.8  5.9      mw  us
# 2  1987-11-30T03:12:37.000Z    30.990     51.170   37.7  4.8      mb  us
# 3  1987-11-27T08:26:43.780Z    32.691     59.100   33.0  4.7      mb  us
# 4  1987-11-25T22:53:29.970Z    28.231     56.753   33.0  4.5      mb  us
# 5  1987-11-24T13:15:29.310Z    32.402     58.890   33.0  4.6      mb  us
# 6  1987-11-24T11:23:16.900Z    32.658     59.105   40.6  5.3      mw  us
# 7  1987-11-09T16:43:42.250Z    32.805     47.799   42.1  4.9      mb  us
# 8  1987-11-03T14:26:41.410Z    28.420     50.439   10.0  4.6      mb  us
# 9  1987-10-28T21:47:25.220Z    27.627     56.374   45.8  4.7      mb  us
#
#            id                   updated        type    status locationSource  \
# 0  usp0003bda  2014-11-07T00:41:24.357Z  earthquake  reviewed             us
# 1  usp0003bd4  2022-04-27T21:27:51.633Z  earthquake  reviewed             us
# 2  usp0003apk  2014-11-07T00:41:16.294Z  earthquake  reviewed             us
# 3  usp0003am3  2020-08-28T21:42:24.936Z  earthquake  reviewed             us
# 4  usp0003ajj  2014-11-07T00:41:15.759Z  earthquake  reviewed             us
# 5  usp0003afd  2014-11-07T00:41:15.063Z  earthquake  reviewed             us
# 6  usp0003af8  2022-04-27T21:30:18.808Z  earthquake  reviewed             us
# 7  usp0003a0e  2014-11-07T00:41:12.852Z  earthquake  reviewed             us
# 8  usp00039v1  2014-11-07T00:41:11.061Z  earthquake  reviewed             us
# 9  usp00039q3  2014-11-07T00:41:07.614Z  earthquake  reviewed             us
#
#   magSource
# 0        us
# 1       hrv
# 2        us
# 3        us
# 4        us
# 5        us
# 6       hrv
# 7        us
# 8        us
# 9        us

# %%
df = df_selected_columns

# %% [markdown]
# #**Remove NaN Value**

# %%
df = df.dropna()
df
# Out:
#                           time  latitude  longitude  depth  mag magType net  \
# 0     1987-12-18T20:54:33.750Z   28.2390    56.6830   33.0  4.6      mb  us
# 1     1987-12-18T16:24:03.050Z   28.1910    56.6770   19.8  5.9      mw  us
# 2     1987-11-30T03:12:37.000Z   30.9900    51.1700   37.7  4.8      mb  us
# 3     1987-11-27T08:26:43.780Z   32.6910    59.1000   33.0  4.7      mb  us
# 4     1987-11-25T22:53:29.970Z   28.2310    56.7530   33.0  4.5      mb  us
# ...                        ...       ...        ...    ...  ...     ...  ..
# 3874  2020-01-04T08:29:18.262Z   31.7534    49.9008   10.0  4.1      mb  us
# 3875  2020-01-04T08:24:38.167Z   25.4990    63.1389   10.0  4.9      mb  us
# 3876  2020-01-02T10:03:06.225Z   34.1629    60.4080   10.0  4.3      mb  us
# 3877  2020-01-02T04:29:06.582Z   34.1326    60.2681   10.0  5.5     mww  us
# 3878  2020-01-01T12:59:03.756Z   30.6259    51.6449   10.0  4.2      mb  us
#
#               id                   updated        type    status  \
# 0     usp0003bda  2014-11-07T00:41:24.357Z  earthquake  reviewed
# 1     usp0003bd4  2022-04-27T21:27:51.633Z  earthquake  reviewed
# 2     usp0003apk  2014-11-07T00:41:16.294Z  earthquake  reviewed
# 3     usp0003am3  2020-08-28T21:42:24.936Z  earthquake  reviewed
# 4     usp0003ajj  2014-11-07T00:41:15.759Z  earthquake  reviewed
# ...          ...                       ...         ...       ...
# 3874  us700071q6  2020-03-21T17:13:50.040Z  earthquake  reviewed
# 3875  us70006ulm  2020-03-21T17:13:35.040Z  earthquake  reviewed
# 3876  us70006th1  2020-03-21T17:13:33.040Z  earthquake  reviewed
# 3877  us70006tev  2022-03-04T17:36:59.119Z  earthquake  reviewed
# 3878  us70006t50  2020-03-21T17:13:31.040Z  earthquake  reviewed
#
#      locationSource magSource
# 0                us        us
# 1                us       hrv
# 2                us        us
# 3                us        us
# 4                us        us
# ...             ...       ...
# 3874             us        us
# 3875             us        us
# 3876             us        us
# 3877             us        us
# 3878             us        us
#
# [3879 rows x 13 columns]

# %% [markdown]
# #**Find and Remove Duplicate Data**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3874    False
# 3875    False
# 3876    False
# 3877    False
# 3878    False
# Length: 3879, dtype: bool

# %% [markdown]
# #**Get Attribute**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3879 entries, 0 to 3878
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            3879 non-null   object
#  1   latitude        3879 non-null   float64
#  2   longitude       3879 non-null   float64
#  3   depth           3879 non-null   float64
#  4   mag             3879 non-null   float64
#  5   magType         3879 non-null   object
#  6   net             3879 non-null   object
#  7   id              3879 non-null   object
#  8   updated         3879 non-null   object
#  9   type            3879 non-null   object
#  10  status          3879 non-null   object
#  11  locationSource  3879 non-null   object
#  12  magSource       3879 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 394.1+ KB

# %%
# Pemeriksaan nilai null di setiap kolom
null_counts = df.isnull().sum()

# Menampilkan jumlah nilai null di setiap kolom
print(null_counts)
# Out:
# time              0
# latitude          0
# longitude         0
# depth             0
# mag               0
# magType           0
# net               0
# id                0
# updated           0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64

# %%
# Pemeriksaan nilai na di setiap kolom
na_counts = df.isna().sum()

# Menampilkan jumlah nilai null di setiap kolom
print(na_counts)
# Out:
# time              0
# latitude          0
# longitude         0
# depth             0
# mag               0
# magType           0
# net               0
# id                0
# updated           0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64
