# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import numpy as np
import graphviz
import math
import seaborn as sns

from datetime import datetime
from matplotlib import pyplot as plt
from IPython.display import Image
from datetime import timedelta
from scipy import optimize
from scipy import stats
from mpl_toolkits.mplot3d import axes3d
from matplotlib import pyplot as plt
from datetime import timedelta, datetime

# %matplotlib inline

# %% [markdown]
# #**Read Earthquake Datasset**

# %%
dataset1 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Indonesia/query1.csv"
dataset2 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Indonesia/query2.csv"
dataset3 = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/Disertation/Indonesia/query3.csv"
# Load each dataset
df1 = pd.read_csv(dataset1)
df2 = pd.read_csv(dataset2)
df3 = pd.read_csv(dataset3)

# Concatenate the datasets
merged_df = pd.concat([df1, df2, df3], ignore_index=True)

# Display the merged DataFrame
merged_df.head(10)
# Out:
#                        time  latitude  longitude    depth  mag magType    nst  \
# 0  2022-12-30T12:10:45.211Z   -7.9548   128.8795   35.000  5.0      mb   62.0
# 1  2022-12-30T06:47:45.290Z   -0.1964    97.2636   16.955  4.6      mb   42.0
# 2  2022-12-30T04:33:52.652Z   -7.0561   102.8060   10.000  5.0      mb   49.0
# 3  2022-12-30T04:16:55.929Z   -0.2207    97.3016   10.000  5.0      mb   69.0
# 4  2022-12-30T03:53:25.133Z    3.7425    97.7725   10.000  4.7      mb   14.0
# 5  2022-12-29T23:26:47.453Z   -0.2127    97.3082   10.000  5.3      mb  165.0
# 6  2022-12-29T16:52:35.854Z    2.0797   127.1383  104.677  4.9      mb  123.0
# 7  2022-12-29T13:35:53.704Z   -3.0102   127.7636   49.136  4.5      mb   24.0
# 8  2022-12-29T08:07:52.147Z   -7.1715   122.4614   10.067  4.5      mb   34.0
# 9  2022-12-28T03:49:55.306Z   -3.3841   130.8043   10.000  5.0      mb   90.0
#
#      gap   dmin   rms  ...                   updated  \
# 0   56.0  2.396  0.54  ...  2023-03-07T18:59:59.040Z
# 1  190.0  1.523  0.81  ...  2023-03-07T18:59:59.040Z
# 2   48.0  4.537  0.60  ...  2023-03-07T18:59:59.040Z
# 3   71.0  1.539  0.67  ...  2023-03-07T18:59:59.040Z
# 4  126.0  1.690  0.81  ...  2023-03-07T19:00:09.040Z
# 5   40.0  1.530  0.57  ...  2023-03-07T18:59:58.040Z
# 6   80.0  1.319  0.90  ...  2023-03-07T18:59:58.040Z
# 7   63.0  3.778  0.88  ...  2023-03-07T18:59:58.040Z
# 8  106.0  1.472  0.65  ...  2023-03-07T18:59:57.040Z
# 9   61.0  1.515  0.67  ...  2023-03-07T18:59:54.040Z
#
#                                  place        type horizontalError depthError  \
# 0  216 km ENE of Lospalos, Timor Leste  earthquake            3.41      1.898
# 1      272 km SW of Sibolga, Indonesia  earthquake            9.02      5.639
# 2      southwest of Sumatra, Indonesia  earthquake            7.32      1.595
# 3      272 km SW of Sibolga, Indonesia  earthquake            7.92      1.808
# 4                                  NaN  earthquake            6.02      1.906
# 5      271 km SW of Sibolga, Indonesia  earthquake            3.61      1.779
# 6      104 km WNW of Tobelo, Indonesia  earthquake            6.89      5.172
# 7        89 km NNW of Ambon, Indonesia  earthquake            7.79      8.930
# 8       162 km N of Maumere, Indonesia  earthquake            6.62      2.796
# 9        209 km E of Amahai, Indonesia  earthquake            7.10      1.814
#
#    magError  magNst    status  locationSource magSource
# 0     0.067    71.0  reviewed              us        us
# 1     0.114    26.0  reviewed              us        us
# 2     0.097    38.0  reviewed              us        us
# 3     0.070    67.0  reviewed              us        us
# 4     0.276     6.0  reviewed              us        us
# 5     0.051   129.0  reviewed              us        us
# 6     0.055   114.0  reviewed              us        us
# 7     0.157    13.0  reviewed              us        us
# 8     0.135    18.0  reviewed              us        us
# 9     0.069    66.0  reviewed              us        us
#
# [10 rows x 22 columns]

# %%
df = merged_df

# %%
# Mengambil hanya kolom yang diinginkan
selected_columns = ['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'net', 'id', 'updated', 'type', 'status', 'locationSource', 'magSource']
df_selected_columns = df[selected_columns]

# Menampilkan DataFrame yang hanya berisi kolom yang dipilih
df_selected_columns.head(10)
# Out:
#                        time  latitude  longitude    depth  mag magType net  \
# 0  2022-12-30T12:10:45.211Z   -7.9548   128.8795   35.000  5.0      mb  us
# 1  2022-12-30T06:47:45.290Z   -0.1964    97.2636   16.955  4.6      mb  us
# 2  2022-12-30T04:33:52.652Z   -7.0561   102.8060   10.000  5.0      mb  us
# 3  2022-12-30T04:16:55.929Z   -0.2207    97.3016   10.000  5.0      mb  us
# 4  2022-12-30T03:53:25.133Z    3.7425    97.7725   10.000  4.7      mb  us
# 5  2022-12-29T23:26:47.453Z   -0.2127    97.3082   10.000  5.3      mb  us
# 6  2022-12-29T16:52:35.854Z    2.0797   127.1383  104.677  4.9      mb  us
# 7  2022-12-29T13:35:53.704Z   -3.0102   127.7636   49.136  4.5      mb  us
# 8  2022-12-29T08:07:52.147Z   -7.1715   122.4614   10.067  4.5      mb  us
# 9  2022-12-28T03:49:55.306Z   -3.3841   130.8043   10.000  5.0      mb  us
#
#            id                   updated        type    status locationSource  \
# 0  us7000j11x  2023-03-07T18:59:59.040Z  earthquake  reviewed             us
# 1  us7000j10t  2023-03-07T18:59:59.040Z  earthquake  reviewed             us
# 2  us7000j0zy  2023-03-07T18:59:59.040Z  earthquake  reviewed             us
# 3  us7000j0zu  2023-03-07T18:59:59.040Z  earthquake  reviewed             us
# 4  us7000j3ns  2023-03-07T19:00:09.040Z  earthquake  reviewed             us
# 5  us7000j0y6  2023-03-07T18:59:58.040Z  earthquake  reviewed             us
# 6  us7000j0va  2023-03-07T18:59:58.040Z  earthquake  reviewed             us
# 7  us7000j0ub  2023-03-07T18:59:58.040Z  earthquake  reviewed             us
# 8  us7000j0sv  2023-03-07T18:59:57.040Z  earthquake  reviewed             us
# 9  us7000j0kg  2023-03-07T18:59:54.040Z  earthquake  reviewed             us
#
#   magSource
# 0        us
# 1        us
# 2        us
# 3        us
# 4        us
# 5        us
# 6        us
# 7        us
# 8        us
# 9        us

# %%
df = df_selected_columns

# %% [markdown]
# #**Remove NaN Value**

# %%
df = df.dropna()
df
# Out:
#                            time  latitude  longitude    depth   mag magType  \
# 0      2022-12-30T12:10:45.211Z   -7.9548   128.8795   35.000  5.00      mb
# 1      2022-12-30T06:47:45.290Z   -0.1964    97.2636   16.955  4.60      mb
# 2      2022-12-30T04:33:52.652Z   -7.0561   102.8060   10.000  5.00      mb
# 3      2022-12-30T04:16:55.929Z   -0.2207    97.3016   10.000  5.00      mb
# 4      2022-12-30T03:53:25.133Z    3.7425    97.7725   10.000  4.70      mb
# ...                         ...       ...        ...      ...   ...     ...
# 36782  1972-01-29T20:34:13.610Z   -5.4410   131.3920   61.200  5.57      mw
# 36783  1972-01-26T03:41:57.830Z   -2.5430   102.5350  171.100  5.53      mw
# 36784  1972-01-18T07:31:18.370Z   -6.2390   104.0250   57.800  5.55      mw
# 36785  1972-01-07T06:25:50.000Z   -2.1840   138.9510   30.000  6.00      mw
# 36786  1972-01-04T18:09:47.420Z   -0.1090   125.0230   28.400  5.62      mw
#
#           net            id                   updated        type    status  \
# 0          us    us7000j11x  2023-03-07T18:59:59.040Z  earthquake  reviewed
# 1          us    us7000j10t  2023-03-07T18:59:59.040Z  earthquake  reviewed
# 2          us    us7000j0zy  2023-03-07T18:59:59.040Z  earthquake  reviewed
# 3          us    us7000j0zu  2023-03-07T18:59:59.040Z  earthquake  reviewed
# 4          us    us7000j3ns  2023-03-07T19:00:09.040Z  earthquake  reviewed
# ...       ...           ...                       ...         ...       ...
# 36782  iscgem  iscgem777336  2022-04-26T20:58:27.171Z  earthquake  reviewed
# 36783  iscgem  iscgem777243  2022-04-26T20:58:00.973Z  earthquake  reviewed
# 36784  iscgem  iscgem777003  2022-04-26T20:57:36.784Z  earthquake  reviewed
# 36785  iscgem  iscgem776759  2022-04-26T20:57:20.537Z  earthquake  reviewed
# 36786  iscgem  iscgem776687  2022-05-09T22:49:38.035Z  earthquake  reviewed
#
#       locationSource magSource
# 0                 us        us
# 1                 us        us
# 2                 us        us
# 3                 us        us
# 4                 us        us
# ...              ...       ...
# 36782         iscgem    iscgem
# 36783         iscgem    iscgem
# 36784         iscgem    iscgem
# 36785         iscgem    iscgem
# 36786         iscgem    iscgem
#
# [36787 rows x 13 columns]

# %% [markdown]
# #**Find and Remove Duplicate Data**

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36782    False
# 36783    False
# 36784    False
# 36785    False
# 36786    False
# Length: 36787, dtype: bool

# %% [markdown]
# #**Get Attribute**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36787 entries, 0 to 36786
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            36787 non-null  object
#  1   latitude        36787 non-null  float64
#  2   longitude       36787 non-null  float64
#  3   depth           36787 non-null  float64
#  4   mag             36787 non-null  float64
#  5   magType         36787 non-null  object
#  6   net             36787 non-null  object
#  7   id              36787 non-null  object
#  8   updated         36787 non-null  object
#  9   type            36787 non-null  object
#  10  status          36787 non-null  object
#  11  locationSource  36787 non-null  object
#  12  magSource       36787 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 3.6+ MB

# %%
# Pemeriksaan nilai na di setiap kolom
na_counts = df.isna().sum()

# Menampilkan jumlah nilai null di setiap kolom
print(na_counts)
# Out:
# time              0
# latitude          0
# longitude         0
# depth             0
# mag               0
# magType           0
# net               0
# id                0
# updated           0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64

# %%
# Pemeriksaan nilai null di setiap kolom
null_counts = df.isnull().sum()

# Menampilkan jumlah nilai null di setiap kolom
print(null_counts)
# Out:
# time              0
# latitude          0
# longitude         0
# depth             0
# mag               0
# magType           0
# net               0
# id                0
# updated           0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64
